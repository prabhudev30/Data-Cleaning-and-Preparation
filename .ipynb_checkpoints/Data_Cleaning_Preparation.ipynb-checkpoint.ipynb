# %% [markdown]
# ## 1. Import Required Libraries

# %%
import pandas as pd
import numpy as np

print("Libraries imported successfully")
# Out:
# Libraries imported successfully

# %% [markdown]
# ## 2. Loading the Dataset

# %%
file_path = "Dataset/Global_Superstore.csv"

df = pd.read_csv(file_path)

df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 file_path = "Dataset/Global_Superstore.csv"
#       2
# ----> 3 df = pd.read_csv(file_path)
#       4
#       5 df.head()
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
# ...

# %%
import os

os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Cleaned_Global_Superstore.csv',
#  'Data_Cleaning_and_Preparation.ipynb.ipynb',
#  'Data_Cleaning_Preparation.ipynb.ipynb',
#  'README.md.txt']

# %%
file_path = "Cleaned_Global_Superstore.csv"

df = pd.read_csv(file_path)

df.head()
# Out:
#    Order_ID         Category  Sales  Profit
# 0       101       Technology   5000     500
# 1       102        Furniture   3000     200
# 2       103  Office Supplies   1500     100
# 3       104       Technology   7000     800

# %% [markdown]
# ## 3. Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Order_ID  4 non-null      int64
#  1   Category  4 non-null      str
#  2   Sales     4 non-null      int64
#  3   Profit    4 non-null      int64
# dtypes: int64(3), str(1)
# memory usage: 260.0 bytes

# %% [markdown]
# ## 5. Checking Missing Values

# %%
df.isnull().sum()
# Out:
# Order_ID    0
# Category    0
# Sales       0
# Profit      0
# dtype: int64

# %% [markdown]
# ## 6. Removing Duplicate Records

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

print("Duplicates removed")
# Out:
# Duplicates removed

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

print("Duplicates removed successfully")
# Out:
# Duplicates removed successfully

# %%
df.dtypes
# Out:
# Order_ID    int64
# Category      str
# Sales       int64
# Profit      int64
# dtype: object

# %% [markdown]
# ## 4. Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Order_ID  4 non-null      int64
#  1   Category  4 non-null      str
#  2   Sales     4 non-null      int64
#  3   Profit    4 non-null      int64
# dtypes: int64(3), str(1)
# memory usage: 260.0 bytes

# %% [markdown]
# ## 7. Exporting Cleaned Dataset

# %%
df.to_csv("Cleaned_Final_Global_Superstore.csv", index=False)

print("Cleaned dataset exported successfully")
# Out:
# Cleaned dataset exported successfully

# %% [markdown]
# # Data Cleaning and Preparation Project
#
# ## Objective
# The objective of this project is to clean and prepare a dataset using Python Pandas.
#
# ## Tasks Performed
# - Load the dataset
# - Explore dataset structure
# - Identify missing values
# - Remove duplicate records
# - Check and convert data types
# - Export cleaned dataset as CSV
#
# ## Tools Used
# - Python
# - Jupyter Notebook
# - Pandas
# - NumPy

# %% [markdown]
# ## Dataset Overview
#
# The dataset contains sales-related information used for data cleaning and preparation.
#
# ### Columns Description
#
# | Column Name | Description |
# |------------|-------------|
# | Order_ID | Unique identification number for each order |
# | Category | Product category information |
# | Sales | Total sales value |
# | Profit | Profit earned from sales |
#
# The dataset is checked for:
# - Missing values
# - Duplicate records
# - Incorrect data types

# %% [markdown]
# ## 8. Conclusion
#
# In this project, the Global Superstore dataset was cleaned and prepared using Python Pandas.
#
# The following data preprocessing steps were performed:
#
# - Loaded the dataset into a Pandas DataFrame
# - Analyzed dataset structure and information
# - Checked for missing values
# - Removed duplicate records
# - Verified data types
# - Exported the cleaned dataset into a new CSV file
#
# The cleaned dataset is now ready for further data analysis and visualization.
